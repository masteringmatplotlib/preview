# %% [markdown]
# # A Preview
# *An IPython Notebook for Mastering matplotlib*

# %%
import matplotlib
matplotlib.use('nbagg')

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Joint Plots with Seaborn

# %%
import seaborn as sns 
import numpy as np
from scipy import stats

# %% [markdown]
# As you can see from the import, we're going to use Seaborn for some nice visual presentation:

# %%
sns.set_palette("deep", desat=.6)

# %% [markdown]
# We're also going to use NumPy and SciPy to generate some data. Next, let's get some Seaborn defaults set up:

# %%
np.random.seed(9221999)

# %% [markdown]
# Let's create some random data to use for our visualization:

# %%
x = stats.gamma(5).rvs(420)
y = stats.gamma(13).rvs(420)

# %% [markdown]
# And now, let's plot the data:

# %%
with sns.axes_style("white"):
    sns.jointplot(x, y, kind="hex", size=16);

# %% [markdown]
# ## Scatter Plat Matrix Graphs with Pandas

# %% [markdown]
# Our next preview will be a Pandas teaser:

# %%
import pandas as pd

# %% [markdown]
# Let's set some options:

# %%
pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)

# %% [markdown]
# The Pandas project shops with some sample data that we can load and play with:

# %%
baseball = pd.read_csv("data/baseball.csv")

# %% [markdown]
# Now let's graph it:

# %%
data = pd.scatter_matrix(baseball.loc[:,'r':'sb'], figsize=(24,16), diagonal='kde')
